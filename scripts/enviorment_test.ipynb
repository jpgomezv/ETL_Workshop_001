# %%
# - [Small test to verify the enviorment]

import pandas as pd
import psycopg2
from dotenv import load_dotenv
import os
load_dotenv()
print("Enviorment ready:", os.getenv("DB_NAME"))
# Out:
# Enviorment ready: etl_workshop_db
